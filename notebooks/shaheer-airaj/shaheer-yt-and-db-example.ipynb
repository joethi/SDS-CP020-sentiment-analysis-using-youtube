# %% [markdown]
# # Grabbing YouTube comments

# %%
import os
import googleapiclient.discovery
from dotenv import load_dotenv
load_dotenv()

YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")

if not YOUTUBE_API_KEY:
    raise ValueError("YOUTUBE_API_KEY not loaded. Please check your .env file.")
# Out:
# YOUTUBE_API_KEY successfully loaded

# %%
api_service_name = "youtube"
api_version = "v3"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = YOUTUBE_API_KEY)

request = youtube.commentThreads().list(
    part="snippet,replies",
    videoId="-2k1rcRzsLA"
)
response = request.execute()

# %% [markdown]
# The response object returns a dictionary with some very comprehensive information

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'siH11pIYr1xfaDCRYzlWMPb92Rc',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpSklCZ0FFZ1VJaUNBWUFCSUZDS2dnR0FBU0JRaUhJQmdBSWcwS0N3aW51dGU4QmhDb2k4ZGU=',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'jACuBxSzZRuMzPGKqnjLeBlAR_M',
#    'id': 'UgzJNA5OXuCx1euq6n94AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gzHU2XVklFyYYGsUkIs6fG0kUVU',
#      'id': 'UgzJNA5OXuCx1euq6n94AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'This time even Hainan Island is missing. Why can&#39;t you build a competent AI? It’s because you fail to get even the most basic information right—once again, an erroneous map is presented upfront.',
#       'textOriginal': "This time even Hainan Island is missing. Why can't you build a competent AI? It’s because you fail to get even the most basic information right—once again, an erroneous map is presented upfront.",
#       'authorDisplayName': '@正文Eureka',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lM8olcIw9NFMc64e_orAmItJ7RVY_1CxYR5VpPpAd_XQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@%E6%AD%A3%E6%96%87Eureka',
#       'authorChannelId': {'value': 'UC9zy4UTGVk9CoEeiMui7GGw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T10:31:21Z',
#       'updatedAt': '2025-01-26T10:31:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yq5LR60PBmMtpbal2zZCatTZOcU',
#    'id': 'UgxjxJyygH_3GY_y3bp4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Yn2361JKXhBQVG9-aNd4JleL4dE',
#      'id': 'UgxjxJyygH_3GY_y3bp4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Is this better for bouncing ideas off of about things in law/sociology/anthropology topics than something like Claude?',
#       'textOriginal': 'Is this better for bouncing ideas off of about things in law/sociology/anthropology topics than something like Claude?',
#       'authorDisplayName': '@dylanhuntly3517',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nD0BBNDkq8xXndN6Gq7CyWGeGJ9ZEIVJqH49uf2uZ23fc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@dylanhuntly3517',
#       'authorChannelId': {'value': 'UCiqorPk3ABF05QwczWQfgYg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T09:59:30Z',
#       'updatedAt': '2025-01-26T09:59:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MgRwh1CP0ivRvYW1-kZSnssU5bw',
#    'id': 'UgwoRWgzA2wyljdHoIt4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9NQPAmymj32CS3m8gjzIaCwsoDA',
#      'id': 'UgwoRWgzA2wyljdHoIt4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'lol',
#       'textOriginal': 'lol',
#       'authorDisplayName': '@贝娜丽莎',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/US1IEimQsWmFLStUHPy9ciy0hGtpYYfuaFeyKTS_LTV6stfOIGOhTYJW7TIJz1HWsHZlmzRc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@%E8%B4%9D%E5%A8%9C%E4%B8%BD%E8%8E%8E',
#       'authorChannelId': {'value': 'UCSXYuZl80p7gx3aYaYNQdVw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T09:46:20Z',
#       'updatedAt': '2025-01-26T09:46:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MwHp2EDkEyyrx7e4I5r0-oqyEIE',
#    'id': 'Ugyec8ns0JwIReTH4-54AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'b5i43MXuQi2tDtvvd7JTgXqBI0Y',
#      'id': 'Ugyec8ns0JwIReTH4-54AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'i watch either this channel or linus tech tips after postnut clarity hits me ... then i fall sleep.. every night',
#       'textOriginal': 'i watch either this channel or linus tech tips after postnut clarity hits me ... then i fall sleep.. every night',
#       'authorDisplayName': '@ipchwn',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lRRQRkPVLuVEqBQqbicEvGkuN3AqlsqCu1Ty4UJi0BtFrrVMBaDYNSNUGINQ8sYTXcMQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ipchwn',
#       'authorChannelId': {'value': 'UCfY8RludLz_jJfdb9HAMbfA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T09:43:29Z',
#       'updatedAt': '2025-01-26T09:43:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Mcw5FP7lTbv9ra9F9iw8wWKYlyY',
#    'id': 'UgxI77-A-733s22_ZPx4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zzOLRE6fHJMrYSlbGhN5zPCoRzM',
#      'id': 'UgxI77-A-733s22_ZPx4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'The age of AGI is here ❤🚀🚀❤️',
#       'textOriginal': 'The age of AGI is here ❤🚀🚀❤️',
#       'authorDisplayName': '@NextFuckingLevel',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nEjbsjHgs_YHWLlWe4Jk4Z_HuDKPiAe7KoKuEN-MMIwwA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@NextFuckingLevel',
#       'authorChannelId': {'value': 'UCyjN7RLnrZ3kEKQgi69D1Lw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T09:33:14Z',
#       'updatedAt': '2025-01-26T09:33:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0VPL4hysaaK5uBN3itvPAxagmBY',
#    'id': 'UgxMuGH0w5_wSEUXuZR4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tHEXm5ECRbNWSj8FSbapUybS2cg',
#      'id': 'UgxMuGH0w5_wSEUXuZR4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': '科學沒有政治、性別、階級之分！',
#       'textOriginal': '科學沒有政治、性別、階級之分！',
#       'authorDisplayName': '@Alex-ji3me',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n2udBzeYBteVO94AOvACDKqyHN4sBTqV2YenVzO3Y2Ic5h7sd9c1UhQi-g7V9kvb_L3A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Alex-ji3me',
#       'authorChannelId': {'value': 'UCa9-vEPYuGH21QyClJLai9g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T09:16:32Z',
#       'updatedAt': '2025-01-26T09:16:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nml6p1nNJKre2-r-9s--XgkRFxc',
#    'id': 'UgwKB408xpS2K2VISe54AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5iR6HV42ucIkHtSaNJ1A7SIk6nI',
#      'id': 'UgwKB408xpS2K2VISe54AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Idk kinda the same if not worse.',
#       'textOriginal': 'Idk kinda the same if not worse.',
#       'authorDisplayName': '@ghostafridi8255',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lT2wXZ4rBJQve_11ag2cCQaFxodlxETR3FDcRPeHi6LC4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ghostafridi8255',
#       'authorChannelId': {'value': 'UCv7kLtNDEhk1M4lBkTw_jLA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T08:56:11Z',
#       'updatedAt': '2025-01-26T08:56:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UE2ei1M_pbDY_s9sKTJ-Ep4gohk',
#    'id': 'Ugyz5WJhR8gj62x_Fg54AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Lp7lkrQ1POSNY4W79EdT-P2ySXY',
#      'id': 'Ugyz5WJhR8gj62x_Fg54AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=-2k1rcRzsLA&amp;t=2">0:02</a> where is hainan island?',
#       'textOriginal': '0:02 where is hainan island?',
#       'authorDisplayName': '@ryana5435',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_knMC4A4dYQRepxf2T2Vac2yNx1KEwdRnKoQn0mHIk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ryana5435',
#       'authorChannelId': {'value': 'UCeJXQmIfzQq4-81goPXQ4sA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T08:46:56Z',
#       'updatedAt': '2025-01-26T08:46:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'S8BqdKCgBhT0U_wcxvHBjEAJY8s',
#    'id': 'UgzCtO3rOW5eWkE6LbB4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hU68xMVXf0H-tphggq28DiyVyhM',
#      'id': 'UgzCtO3rOW5eWkE6LbB4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Nice.. that it is open source.... other wise these us startuos will use ai to control our mind ... and will kill whistle blowers',
#       'textOriginal': 'Nice.. that it is open source.... other wise these us startuos will use ai to control our mind ... and will kill whistle blowers',
#       'authorDisplayName': '@Ansh_Rajpoot_',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/iyubNIJ8yPT0GN2kw7Udv4TKc-iA9U9bR_CWrvAfx1jvp9BzMja3sRcjAZYQ0oz6Y5puE66LIn4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Ansh_Rajpoot_',
#       'authorChannelId': {'value': 'UCVAtc6y-kV6CbsuDb1QyBhw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T08:46:08Z',
#       'updatedAt': '2025-01-26T08:46:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3Z5RBIDez_kuF7JdJX2ahRYOd88',
#    'id': 'UgxgqgEZTjWiYsUYC-h4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AB1tkfVJIQL0zJdFFQNnZpkcbYM',
#      'id': 'UgxgqgEZTjWiYsUYC-h4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'And this is <i>actually</i> open source unlike &quot;Open&quot;AI. Great to see!',
#       'textOriginal': 'And this is _actually_ open source unlike "Open"AI. Great to see!',
#       'authorDisplayName': '@st.altair4936',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/QsB7YG0Nmo5PZg6wt1EmGe3brQ-Q89EfysYOHlvxitqVL95uAzML5hGKaKD_3Cdwy9iK4LETgQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@st.altair4936',
#       'authorChannelId': {'value': 'UCOSjY4XMRjBRNhStQgwSNVg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-01-26T08:40:57Z',
#       'updatedAt': '2025-01-26T08:40:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fnh_IcLrT49yGN5k6MNX_z1K1Pk',
#    'id': 'UgyqCzNgv9O2hBsI7sp4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bJzrvFSoY6yRvXQ2O4nyX9SQ5eU',
#      'id': 'UgyqCzNgv9O2hBsI7sp4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': '美国的朋友们你们搜索不会遇到“对不起，我无法回答这个问题”吗？',
#       'textOriginal': '美国的朋友们你们搜索不会遇到“对不起，我无法回答这个问题”吗？',
#       'authorDisplayName': '@simpleChinese-e6n',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/d5sDzTIPKfe2HetKu2D64VtbZt0HZSoHCi0PS8skB9MpIf7c_uh5-ApDYijQVVPU0DarbrVO=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@simpleChinese-e6n',
#       'authorChannelId': {'value': 'UC2gk332-i6pMzmXLEyMvTyw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T08:30:42Z',
#       'updatedAt': '2025-01-26T08:30:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EVwkK-8CV9bxKjaiFRbMnAM9FSQ',
#    'id': 'UgwWwu-a27Da68p4pnZ4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3LYYle-xTWg1HGp-KJb0SfliLvo',
#      'id': 'UgwWwu-a27Da68p4pnZ4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Saying AI is human smart, is like saying submarines can swim. A two year old has more intelligence than all these so called “intelligent” databases programmed to do what WE tell them to do',
#       'textOriginal': 'Saying AI is human smart, is like saying submarines can swim. A two year old has more intelligence than all these so called “intelligent” databases programmed to do what WE tell them to do',
#       'authorDisplayName': '@omidsouresrafil7386',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mzxl9o1Sq8QMd2vhFG1d69CXSRj1-IEbTA-IPCWvPRlg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@omidsouresrafil7386',
#       'authorChannelId': {'value': 'UCGLNFUhx3P-3ZyYV7xMdZ6g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T08:11:49Z',
#       'updatedAt': '2025-01-26T08:11:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'j7r7fAJbwnWzcjyaZMYcmfcC9mA',
#    'id': 'UgweStERUwjjhNdCKHx4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ZpnHt8QAVOka49683xv0_KVs6eA',
#      'id': 'UgweStERUwjjhNdCKHx4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'I’ll come back here to finish the whole video tomorrow after I take a good shower, eat a healthy breakfast with berries, eggs, and an organic orange, complete my gym session and sauna, have a cup of coffee, and pray, InshaAllah!',
#       'textOriginal': 'I’ll come back here to finish the whole video tomorrow after I take a good shower, eat a healthy breakfast with berries, eggs, and an organic orange, complete my gym session and sauna, have a cup of coffee, and pray, InshaAllah!',
#       'authorDisplayName': '@zuberkariye2299',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mM9OChU62JwM199DosYeN7sBP24iCahedv232jI-U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@zuberkariye2299',
#       'authorChannelId': {'value': 'UCnvRnCYFcogt4StV6EZJPCA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:56:31Z',
#       'updatedAt': '2025-01-26T07:56:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TjbNygaF0I14j1Vq-ZNsTUCjG04',
#    'id': 'Ugwa4p2_O9LW65jqUQ94AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'HNTEakbkHXhUnlmf-9V3PDJgIFw',
#      'id': 'Ugwa4p2_O9LW65jqUQ94AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Bruh wtf happened with me. I threw a physics problem at DeepSeek r1, ChatGPT plus thing on my friends account, and Gemini Flash thinking experimental model on Google AI studio.<br><br>DeepSeek with DeepThink took over 3 min 24 sec to give the correct answer.<br><br>ChatGPT got the right answer in 45 seconds<br><br>Gemini Thinking Flash gave the right answer in 12 seconds.<br><br>All of them gave detailed steps and reasons for them. ChatGPt gave more details, then Gemini, then DeepSeek.<br><br><br>Later I asked them for the exact answer. <br>DeepSeek took over 4 min.<br>ChaltGPT took 2 sec.<br>Gemini gave an answer in fraction (that&#39;s the most accurate) and then when asked gave in 30 decimal places in 8 sec and 6 sec respectively.',
#       'textOriginal': "Bruh wtf happened with me. I threw a physics problem at DeepSeek r1, ChatGPT plus thing on my friends account, and Gemini Flash thinking experimental model on Google AI studio.\n\nDeepSeek with DeepThink took over 3 min 24 sec to give the correct answer.\n\nChatGPT got the right answer in 45 seconds\n\nGemini Thinking Flash gave the right answer in 12 seconds.\n\nAll of them gave detailed steps and reasons for them. ChatGPt gave more details, then Gemini, then DeepSeek.\n\n\nLater I asked them for the exact answer. \nDeepSeek took over 4 min.\nChaltGPT took 2 sec.\nGemini gave an answer in fraction (that's the most accurate) and then when asked gave in 30 decimal places in 8 sec and 6 sec respectively.",
#       'authorDisplayName': '@droppyalmond1111',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/MZoCasV8N9ujwPLlxVRV-jq_G3x-kRJ_rKDqrqua95UbsL8tRKhSBQM_-yOODYsqwvPcNYY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@droppyalmond1111',
#       'authorChannelId': {'value': 'UCT-3APnCtgE0X2grSiX1-og'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:50:19Z',
#       'updatedAt': '2025-01-26T07:50:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'x2bL8drFpEJnD0BLG142z8DVisM',
#       'id': 'Ugwa4p2_O9LW65jqUQ94AaABAg.ADkUzimYoCtADkb4YHp2r_',
#       'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#        'videoId': '-2k1rcRzsLA',
#        'textDisplay': 'still deepseek r1 is free and accurate',
#        'textOriginal': 'still deepseek r1 is free and accurate',
#        'parentId': 'Ugwa4p2_O9LW65jqUQ94AaABAg',
#        'authorDisplayName': '@zookaroo2132',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kbXxYItbEfaXzPcW5Gc9NJamEUvIqdlE49zqOjLXocGzY=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@zookaroo2132',
#        'authorChannelId': {'value': 'UCv_M-9rEXYri04ad7sLFt5Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2025-01-26T08:52:17Z',
#        'updatedAt': '2025-01-26T08:52:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'vVXBzoGAc2GLml4GY-GLHVnvpW0',
#       'id': 'Ugwa4p2_O9LW65jqUQ94AaABAg.ADkUzimYoCtADkdrbgM1IT',
#       'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#        'videoId': '-2k1rcRzsLA',
#        'textDisplay': '@@zookaroo2132 <br>Absolutely! I am not complaining about that.<br><br>I want to say why is everyone saying DeepSeek has destroyed the competition and will dethrone america from the ai race and all that stuff, also on twitter',
#        'textOriginal': '@@zookaroo2132 \nAbsolutely! I am not complaining about that.\n\nI want to say why is everyone saying DeepSeek has destroyed the competition and will dethrone america from the ai race and all that stuff, also on twitter',
#        'parentId': 'Ugwa4p2_O9LW65jqUQ94AaABAg',
#        'authorDisplayName': '@droppyalmond1111',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/MZoCasV8N9ujwPLlxVRV-jq_G3x-kRJ_rKDqrqua95UbsL8tRKhSBQM_-yOODYsqwvPcNYY=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@droppyalmond1111',
#        'authorChannelId': {'value': 'UCT-3APnCtgE0X2grSiX1-og'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2025-01-26T09:16:35Z',
#        'updatedAt': '2025-01-26T09:16:35Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0p1hW9ymRIN_yXdEZNuZkzDRRtM',
#    'id': 'UgyZjCdzgCg5Us-CzF94AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'qneJAnsH9sf4qUi3pOFUkXo1IwM',
#      'id': 'UgyZjCdzgCg5Us-CzF94AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Now if only Brilliant is free',
#       'textOriginal': 'Now if only Brilliant is free',
#       'authorDisplayName': '@lizrich924',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/66LjF0wfkbe8kEbc9VVJLTbiddoAZ4LVtA1sCBhB6ZDd5HBYNeC4MJIZJNy1HGSUs3TEO_FGWA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@lizrich924',
#       'authorChannelId': {'value': 'UCnryZL8MtEYfWfEIX17rznA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:43:49Z',
#       'updatedAt': '2025-01-26T07:43:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ts6LvtBS1TnFMElwe2pfdTKXrjw',
#    'id': 'UgyWzjnulR2uUYSREgZ4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'i1XS4GSSEj-q6uR3qvvbkm0BH-M',
#      'id': 'UgyWzjnulR2uUYSREgZ4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'When OpenAI released ChatGPT, did you say &quot;Yesterday the US released ChatGPT...&quot;?',
#       'textOriginal': 'When OpenAI released ChatGPT, did you say "Yesterday the US released ChatGPT..."?',
#       'authorDisplayName': '@hyeung1',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mQKOGQl6TZadBBdyyA47mBQTv1pg6hmXF-Ma3P6Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@hyeung1',
#       'authorChannelId': {'value': 'UC9IDUe5RgyOXlqHX2EX21dw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:43:24Z',
#       'updatedAt': '2025-01-26T07:43:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'g1aGapJK9BGpuHtVko-pvZJDKKo',
#    'id': 'UgxZzjSY9MJ89fC3p9N4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SApPRbx4v502ONX5QfWLGk4NEcs',
#      'id': 'UgxZzjSY9MJ89fC3p9N4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'If it cost less to train and develop these models using older GPU’s where does the money go now ? Does Nvidia value drop?',
#       'textOriginal': 'If it cost less to train and develop these models using older GPU’s where does the money go now ? Does Nvidia value drop?',
#       'authorDisplayName': '@sabelokhanyile',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l342wGaG5EAmUDQN7q4yi6iNmn9hmgu4qe1AFmePcZtyU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@sabelokhanyile',
#       'authorChannelId': {'value': 'UCDU0A2AsvN5QkmwslZg2L8g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:28:54Z',
#       'updatedAt': '2025-01-26T07:28:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9Fxw5fEQOwYjI4NXBrmNYbD_TnU',
#    'id': 'UgyonZQXzNVvzCWvJxl4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nsjinUDwQ046eMDKO9cFPXVQF7s',
#      'id': 'UgyonZQXzNVvzCWvJxl4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'Game over, USA.',
#       'textOriginal': 'Game over, USA.',
#       'authorDisplayName': '@foxtrot762',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n1UKC1gAN-YFZhCUog2kUuCJSGEwpbZCeeUyGChCtqFwdMgMoUCpJptjOM5HdMhNgHCg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@foxtrot762',
#       'authorChannelId': {'value': 'UCdNTvXcNgfmVGnxMOc9aOlQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:20:31Z',
#       'updatedAt': '2025-01-26T07:20:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5wpZGHJsglzVdo9WRgRoaco_PKc',
#    'id': 'UgzROt07_EORp3pRqFF4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hOkN2oZbmrmigJU92eqIiQhLWNU',
#      'id': 'UgzROt07_EORp3pRqFF4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': 'China always have weapons against everything.',
#       'textOriginal': 'China always have weapons against everything.',
#       'authorDisplayName': '@kennethsalar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/I5QRKTzp75R3Gcf9ZMSSIcmWwDYiXcb16e6HIs0YdXck5Mb_AgESUBzawFeR_RZz_D6Ig-Wm=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kennethsalar',
#       'authorChannelId': {'value': 'UCJyGzh0C11Nj1UpDrUEIn0A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T07:14:37Z',
#       'updatedAt': '2025-01-26T07:14:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TcnEa_uy-Qfu3ycO7s9c_ff2LD8',
#    'id': 'UgzaNS8zxqe2g0rrp2B4AaABAg',
#    'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#     'videoId': '-2k1rcRzsLA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WIPNSL8KMvKtNt9ANGCPVC9E6l4',
#      'id': 'UgzaNS8zxqe2g0rrp2B4AaABAg',
#      'snippet': {'channelId': 'UCsBjURrPoezykLs9EqgamOA',
#       'videoId': '-2k1rcRzsLA',
#       'textDisplay': '“ Vibes “ always a better rubric',
#       'textOriginal': '“ Vibes “ always a better rubric',
#       'authorDisplayName': '@HarnessedLogistics',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k6ik9k6NPqHs0kvMwv9SpZyE9qUk9AxeJZJ9_zucX5-Srt4Jkr8so6gIcmOMBS08yveQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@HarnessedLogistics',
#       'authorChannelId': {'value': 'UCMnrUdaIZCBI1xepEobDKQg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-01-26T06:58:47Z',
#       'updatedAt': '2025-01-26T06:58:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# To get the comments, let's find the exact key which contains the information we are looking for.

# %%
response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']
# Out:
# 'This time even Hainan Island is missing. Why can&#39;t you build a competent AI? It’s because you fail to get even the most basic information right—once again, an erroneous map is presented upfront.'

# %% [markdown]
# Lets now store all the comments into a list

# %%
comments = []
for item in response['items']:
    comments.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])

# %% [markdown]
# Another shorter way of doing the same thing as above using list comprehension

# %%
comments = [item['snippet']['topLevelComment']['snippet']['textDisplay'] for item in response['items']]

# %%
comments
# Out:
# ['This time even Hainan Island is missing. Why can&#39;t you build a competent AI? It’s because you fail to get even the most basic information right—once again, an erroneous map is presented upfront.',
#  'Is this better for bouncing ideas off of about things in law/sociology/anthropology topics than something like Claude?',
#  'lol',
#  'i watch either this channel or linus tech tips after postnut clarity hits me ... then i fall sleep.. every night',
#  'The age of AGI is here ❤🚀🚀❤️',
#  '科學沒有政治、性別、階級之分！',
#  'Idk kinda the same if not worse.',
#  '<a href="https://www.youtube.com/watch?v=-2k1rcRzsLA&amp;t=2">0:02</a> where is hainan island?',
#  'Nice.. that it is open source.... other wise these us startuos will use ai to control our mind ... and will kill whistle blowers',
#  'And this is <i>actually</i> open source unlike &quot;Open&quot;AI. Great to see!',
#  '美国的朋友们你们搜索不会遇到“对不起，我无法回答这个问题”吗？',
#  'Saying AI is human smart, is like saying submarines can swim. A two year old has more intelligence than all these so called “intelligent” databases programmed to do what WE tell them to do',
#  'I’ll come back here to finish the whole video tomorrow after I take a good shower, eat a healthy breakfast with berries, eggs, and an organic orange, complete my gym session and sauna, have a cup of coffee, and pray, InshaAllah!',
#  'Bruh wtf happened with me. I threw a physics problem at DeepSeek r1, ChatGPT plus thing on my friends account, and Gemini Flash thinking experimental model on Google AI studio.<br><br>DeepSeek with DeepThink took over 3 min 24 sec to give the correct answer.<br><br>ChatGPT got the right answer in 45 seconds<br><br>Gemini Thinking Flash gave the right answer in 12 seconds.<br><br>All of them gave detailed steps and reasons for them. ChatGPt gave more details, then Gemini, then DeepSeek.<br><br><br>Later I asked them for the exact answer. <br>DeepSeek took over 4 min.<br>ChaltGPT took 2 sec.<br>Gemini gave an answer in fraction (that&#39;s the most accurate) and then when asked gave in 30 decimal places in 8 sec and 6 sec respectively.',
#  'Now if only Brilliant is free',
#  'When OpenAI released ChatGPT, did you say &quot;Yesterday the US released ChatGPT...&quot;?',
#  'If it cost less to train and develop these models using older GPU’s where does the money go now ? Does Nvidia value drop?',
#  'Game over, USA.',
#  'China always have weapons against everything.',
#  '“ Vibes “ always a better rubric']

# %%
len(comments)
# Out:
# 20

# %% [markdown]
# Before storing everything into a database, I want to grab some more information regarding the comments.

# %%
authors = [item['snippet']['topLevelComment']['snippet']['authorDisplayName'] for item in response['items']]
rating = [item['snippet']['topLevelComment']['snippet']['viewerRating'] if item['snippet']['topLevelComment']['snippet']['viewerRating'] != 'none' else 0 for item in response['items']]
likes = [item['snippet']['topLevelComment']['snippet']['likeCount'] for item in response['items']]
published = [item['snippet']['topLevelComment']['snippet']['publishedAt'] for item in response['items']]

# %% [markdown]
# We need to structure the data so that it is in the format expected by our database when inserting to tables

# %%
data = []
for i in range(0, len(comments)):
    data.append((authors[i], comments[i], likes[i], rating[i], published[i]))

# %%
data
# Out:
# [('@正文Eureka',
#   'This time even Hainan Island is missing. Why can&#39;t you build a competent AI? It’s because you fail to get even the most basic information right—once again, an erroneous map is presented upfront.',
#   0,
#   0,
#   '2025-01-26T10:31:21Z'),
#  ('@dylanhuntly3517',
#   'Is this better for bouncing ideas off of about things in law/sociology/anthropology topics than something like Claude?',
#   0,
#   0,
#   '2025-01-26T09:59:30Z'),
#  ('@贝娜丽莎', 'lol', 0, 0, '2025-01-26T09:46:20Z'),
#  ('@ipchwn',
#   'i watch either this channel or linus tech tips after postnut clarity hits me ... then i fall sleep.. every night',
#   0,
#   0,
#   '2025-01-26T09:43:29Z'),
#  ('@NextFuckingLevel',
#   'The age of AGI is here ❤🚀🚀❤️',
#   0,
#   0,
#   '2025-01-26T09:33:14Z'),
#  ('@Alex-ji3me', '科學沒有政治、性別、階級之分！', 0, 0, '2025-01-26T09:16:32Z'),
#  ('@ghostafridi8255',
#   'Idk kinda the same if not worse.',
#   0,
#   0,
#   '2025-01-26T08:56:11Z'),
#  ('@ryana5435',
#   '<a href="https://www.youtube.com/watch?v=-2k1rcRzsLA&amp;t=2">0:02</a> where is hainan island?',
#   0,
#   0,
#   '2025-01-26T08:46:56Z'),
#  ('@Ansh_Rajpoot_',
#   'Nice.. that it is open source.... other wise these us startuos will use ai to control our mind ... and will kill whistle blowers',
#   0,
#   0,
#   '2025-01-26T08:46:08Z'),
#  ('@st.altair4936',
#   'And this is <i>actually</i> open source unlike &quot;Open&quot;AI. Great to see!',
#   1,
#   0,
#   '2025-01-26T08:40:57Z'),
#  ('@simpleChinese-e6n',
#   '美国的朋友们你们搜索不会遇到“对不起，我无法回答这个问题”吗？',
#   0,
#   0,
#   '2025-01-26T08:30:42Z'),
#  ('@omidsouresrafil7386',
#   'Saying AI is human smart, is like saying submarines can swim. A two year old has more intelligence than all these so called “intelligent” databases programmed to do what WE tell them to do',
#   0,
#   0,
#   '2025-01-26T08:11:49Z'),
#  ('@zuberkariye2299',
#   'I’ll come back here to finish the whole video tomorrow after I take a good shower, eat a healthy breakfast with berries, eggs, and an organic orange, complete my gym session and sauna, have a cup of coffee, and pray, InshaAllah!',
#   0,
#   0,
#   '2025-01-26T07:56:31Z'),
#  ('@droppyalmond1111',
#   'Bruh wtf happened with me. I threw a physics problem at DeepSeek r1, ChatGPT plus thing on my friends account, and Gemini Flash thinking experimental model on Google AI studio.<br><br>DeepSeek with DeepThink took over 3 min 24 sec to give the correct answer.<br><br>ChatGPT got the right answer in 45 seconds<br><br>Gemini Thinking Flash gave the right answer in 12 seconds.<br><br>All of them gave detailed steps and reasons for them. ChatGPt gave more details, then Gemini, then DeepSeek.<br><br><br>Later I asked them for the exact answer. <br>DeepSeek took over 4 min.<br>ChaltGPT took 2 sec.<br>Gemini gave an answer in fraction (that&#39;s the most accurate) and then when asked gave in 30 decimal places in 8 sec and 6 sec respectively.',
#   0,
#   0,
#   '2025-01-26T07:50:19Z'),
#  ('@lizrich924',
#   'Now if only Brilliant is free',
#   0,
#   0,
#   '2025-01-26T07:43:49Z'),
#  ('@hyeung1',
#   'When OpenAI released ChatGPT, did you say &quot;Yesterday the US released ChatGPT...&quot;?',
#   0,
#   0,
#   '2025-01-26T07:43:24Z'),
#  ('@sabelokhanyile',
#   'If it cost less to train and develop these models using older GPU’s where does the money go now ? Does Nvidia value drop?',
#   0,
#   0,
#   '2025-01-26T07:28:54Z'),
#  ('@foxtrot762', 'Game over, USA.', 0, 0, '2025-01-26T07:20:31Z'),
#  ('@kennethsalar',
#   'China always have weapons against everything.',
#   0,
#   0,
#   '2025-01-26T07:14:37Z'),
#  ('@HarnessedLogistics',
#   '“ Vibes “ always a better rubric',
#   0,
#   0,
#   '2025-01-26T06:58:47Z')]

# %% [markdown]
# # Storing data into a MySQL database

# %%
MYSQL_USERNAME = os.getenv("MYSQL_USERNAME")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")

if not MYSQL_USERNAME:
    raise ValueError("MYSQL_USERNAME not loaded. Please check your .env file.")
if not MYSQL_PASSWORD:
    raise ValueError("MYSQL_PASSWORD not loaded. Please check your .env file.")
# Out:
# MYSQL_USERNAME successfully loaded
# MYSQL_PASSWORD successfully loaded

# %%
import mysql.connector

# Database connection
connection = mysql.connector.connect(
    host="localhost",
    user=MYSQL_USERNAME,
    password=MYSQL_PASSWORD,
    database="youtube_api_project"
)

connection.is_connected()
# Out:
# True

# %%
cursor = connection.cursor()

# Create a table (if not exists)
create_table_query = """
CREATE TABLE IF NOT EXISTS comments_table (
    id INT AUTO_INCREMENT PRIMARY KEY,
    authorName VARCHAR(255),
    comment MEDIUMTEXT,
    likes INT,
    rating INT,
    publishedTime VARCHAR(255)
);
"""
cursor.execute(create_table_query)

# %%
# Insert data into the table
insert_query = "INSERT INTO comments_table (authorName, comment, likes, rating, publishedTime) VALUES (%s, %s, %s, %s, %s)"

cursor.executemany(insert_query, data)

# Commit changes to the database
connection.commit()

print(f"{cursor.rowcount} rows were inserted.")

# Close the cursor and connection
cursor.close()
connection.close()
# Out:
# 20 rows were inserted.
