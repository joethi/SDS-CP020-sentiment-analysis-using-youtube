# %%
from googleapiclient.discovery import build
from dotenv import load_dotenv
from googleapiclient.errors import HttpError
import os

load_dotenv() # take environment variables from .env.

api_key = os.getenv("MY_API_KEY")

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
request = youtube.search().list(
    part="snippet",
    q="schafer5",
    type="channel",
    maxResults=1  # Assuming there's only one channel with this name
)
response = request.execute()
items = response.get("items", [])
if items:
    channel_id = items[0]["snippet"]["channelId"]
    # Now use the channel ID to fetch statistics
    request = youtube.channels().list(
        part='statistics',
        id=channel_id
    )
    channel_response = request.execute()
    print(channel_response)
else:
    print("No channel found")
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'iOetbC0GCGs5Cqj-et0-6jE5s9I', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'f7WTYOLbPq_XXNVQg-AdlO1CZW4', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '100592656', 'subscriberCount': '1410000', 'hiddenSubscriberCount': False, 'videoCount': '239'}}]}

# %%
def get_comments(youtube, video_id, max_results=100):
    comments = []
    next_page_token = None

    while True:
        try:
            response = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=max_results,
                pageToken=next_page_token
            ).execute()

            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']
                comments.append({
                    'text': comment['textDisplay'],
                    'author': comment['authorDisplayName'],
                    'likeCount': comment['likeCount']
                })

                # If the comment has replies, fetch them as well
                if 'replies' in item:
                    for reply_item in item['replies']['comments']:
                        reply = reply_item['snippet']
                        comments.append({
                            'text': reply['textDisplay'],
                            'author': reply['authorDisplayName'],
                            'likeCount': reply['likeCount']
                        })

            # Check if there are more pages
            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break

        except HttpError as e:
            print(f'An HTTP error {e.resp.status} occurred:\n{e.content}')
            break

    return comments

# Build the service object
youtube = build('youtube', 'v3', developerKey=api_key)
# Video ID from the URL you provided
video_id = '_o2v4GZ4x64'

# Fetch comments
all_comments = get_comments(youtube, video_id)

# comment_list=[]
# for comment in all_comments:
#     comment_list.append(comment['text'])

comment_list = [comment['text'] for comment in all_comments]

comment_list
# Out:
# ['🤑 EXCLUSIVE Deals (Bonuses, Discounts, Giveaways) 👉 <a href="https://www.coinbureau.com/deals/">https://www.coinbureau.com/deals/\r</a><br>🥇Bybit $60k rewards + 0% maker fees for 30 days 👉<a href="https://www.coinbureau.com/deals/trading/bybit-cb/">https://www.coinbureau.com/deals/trading/bybit-cb/\r</a><br>🥈OKX $20k bonus + 40% fee discount for life  👉 <a href="https://www.coinbureau.com/deals/trading/okx/">https://www.coinbureau.com/deals/trading/okx/</a>',
#  '$888 coin is king🚀🚀',
#  'you made a mistake in the video, Virtuals is not on solana but on base',
#  'where is the link to the report?',
#  'Dead internet theory is real. Ai bubbles are taking over real content. Tesla phone isn&#39;t real.<br><br>ICP is the best crypto project by a mile right now. Why are they not getting more coverage?',
#  '@@pablog80 I am asking the same question',
#  'The best AI is Sensay',
#  'Sensay 🚀',
#  'AI getting smarter with SensayAI <br>$SNSY',
#  'Game changing $SNSY',
#  '$SNSY 🚀🚀🚀',
#  'SNSY is at the forefront of digital immortality',
#  'where do we find the link to the binance report? thanks!',
#  'im annoyed im only finding this out now... im on it! im involved!',
#  'Can&#39;t mention AI agents and don&#39;t mention SensayAI',
#  '❤❤',
#  'SensayAi 🔥🔥',
#  'Incredible that&#39;s instresting',
#  'Incredible that&#39;s instresting',
#  ':)',
#  '$SNSY',
#  'AI fit the taking',
#  '💯',
#  'Nice',
#  'SensayAi is awesome',
#  '$Cookie',
#  'Sensay $SNSY had a massive pump and it&#39;s topping the AI category',
#  'Guy, you are the best. Learned  so much from your channel on a host of subjects. Thank you',
#  'Speaking as someone developing AI tech, there are likely exploitable loopholes if lots of AI bots are all using similar tech. Could be a money glitch',
#  'hasta la vista <a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a>',
#  'Schwarzenegger flashback courtesy of Guy!',
#  'Though been a fan and sub for quite a while now. But must say... no crypto channel explains more abstract crypto concepts far better than Guy.. My guy.. Your the best bro.. 👍',
#  'How can I transfer $900 to Binance from my OKX wallet with phrase (search dress way entry code caught pull load acoustic tornado vessel retire)',
#  'Just discovered Sensay and I’m loving the idea of chatting with AI! 💬 Can’t wait to try it out.\xa0<br> @asksensay <a href="http://www.youtube.com/results?search_query=%23aichat">#AIChat</a>',
#  'COOL',
#  'RENDER',
#  'may be they are controlling us already XD!',
#  'do you just need to hold ai16z to get a share of the hedge fund profits or do you need to do something with the token ?',
#  'At a basic level all fund managers should use AI to turbo charge momentum. However, if the AI becomes independent, it can supercharge itself beyond reason and create a ponsi scheme.',
#  '<a href="UCkszU2WH9gy1mb0dV-11UJg/A8MfY-_pEIKNr8oP78-AGA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/A8MfY-_pEIKNr8oP78-AGA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/A8MfY-_pEIKNr8oP78-AGA"></a>',
#  'Wow!!!',
#  'SOLIDUS AITECH',
#  '$ASTO holds the patent for AI Agent NFTs',
#  'Wait, did you say control an AI agent. How are you going to control something with an IQ of 2000+. You can now thank you in a millisecond best case scenario of the AI is develop some form of Buddhist kind understanding of interaction. it allows us to survive in a world they rulethe only way that this would stop is if a massive solar flare hit our planet, developed it in so much electromagnetic frequency that it’s fried every AI on the planet and all technology that would be the one thing that the artificial intelligence could never control is real reality fortunate or unfortunate for them or us.',
#  'CertaiK by virtuals 🩵💚🖤🩶🩵💚🖤🩶🩵💚🖤🩶🩵💚🖤🩶🩵💚🖤',
#  'AI agents by virtuals is soo sickkkkkk',
#  'My head is spinning. Amazing stuff. Could you discuss sentient ai or sentience being built in?',
#  'Krypto King has made a superb project. TrenchesAI. Would you look at that please. Thank you so much',
#  'Always superb information. Thank you',
#  'The presumed predictability would be nice.',
#  'It’s when you get ai bots using quantum chips that’s really scary giving them full access to the internet could be a huge mistake',
#  'The glitch out and transition at the end was well done, but your terminator was just as bad as Arnold&#39;s cultural marxist terminator.',
#  'only SENSAY! $SNSY',
#  'check SUPRA',
#  'ICP best for AI in 2025',
#  'God created this world problem and created the solution through Jesus Christ we have to wait for the new heaven and earth and that is not mars',
#  'AI 2.0 agents don&#39;t exist. It was made up to fool people with aspergers',
#  'You will witness a significant downturn for all cryptocurrencies; however, I assure you that $GTAS will remain stable. As the developer, I want to clarify that this project is not intended for everyday trading. It is designed for investors who prefer tangible results over virtual ones.',
#  'Sensay is beast',
#  'Good',
#  'Good project',
#  'like Spock would say , Its Fascinating, the implications and the possibilities are pushing limits of our little universe , called Earth. We must retain control and continue to make human enable decisions , asisited by AI agents, not the other way around.',
#  'sensay have INSANE AI REPLICAS',
#  'So... I went down the Goatse rabbit hole, so to speak... you did warn me',
#  'AI agents?',
#  '&quot;Really interesting to see how Sensay is changing the game with AI! 🚀 <br>I’m excited to see where $SNSY goes over the next year. Definitely one to keep an eye on! 👀&quot;',
#  'Perhaps AI is already using currency between itself',
#  'sensay',
#  'The best AI agents out there, SensayAi',
#  '$SNSY to the moon🚀',
#  'SENSAY🚀🚀🚀',
#  'U all will lose ur jobs',
#  'Yes we will',
#  'Ai beat the worlds best Go player in the world. So I suspect it beating the worlds best monopoly players will be a stroll on the boardwalk.',
#  'agi is coming from cryptos',
#  'It discovered that it needed religion with money as its savior. I believe this is the natural human conclusion. Enter, God.',
#  'Growing up on terminator and iRobot, I can’t help but be paranoid',
#  '<a href="http://www.youtube.com/results?search_query=%23paal">#PAAL</a> <a href="http://www.youtube.com/results?search_query=%23basedai">#BASEDAI</a>',
#  '$PAAL <a href="http://www.youtube.com/results?search_query=%23basedai">#BASEDAI</a>',
#  '$atlas navi 🚀',
#  '$SNSY',
#  '$SNSY',
#  'So your eluding that the value of parachains like polka dot and cosmos would go up based on a demand for interoperability because of a theoretically massive increase in blockchain traffic with millions of ai bits making transactions simotaneously.',
#  'Economy will break within 2 years. The <b>new</b> biggest transfer of wealth is about to happen',
#  'The best project is sensay in Ai project this will give us 50x incoming',
#  'Sensay is beast',
#  '&quot;Really interesting to see how Sensay is changing the game with AI! 🚀 <br>I’m excited to see where $SNSY goes over the next year. Definitely one to keep an eye on! 👀&quot;',
#  'Sensay is revolutionizing how we interact with AI, turning personal experiences into digital legacies. It&#39;s not just tech; it&#39;s a bridge to the future of human connection.',
#  'Beats on Base!! best AI agent project and its just getting started. Check it out@!!',
#  'Danke fürs Teilen. Finanzielle Bildung ist heute entscheidend, um in einem volatilen Markt unglaubliche Belastbarkeit und Disziplin zu zeigen und Strategie und Einsicht meisterhaft auszubalancieren, um Erfolg zu haben. Dieses Engagement für kontinuierliches Lernen ist inspirierend … ich habe es geschafft, meine Ersparnisse in wenigen Wochen von etwa 100.000 auf anständige 340.000 zu steigern … Ich bin besonders James Musgrave dankbar, dessen umfassende Erfahrung und traditioneller Handelssinn sich in dieser komplexen, sich ständig verändernden Finanzlandschaft als unschätzbar wertvoll erwiesen haben.',
#  'Sensay ($SNSY) is the next big thing in the AI and blockchain space, and here&#39;s why you should jump on the bandwagon',
#  'near protocol lunch a few bilion AI Agent',
#  'Fetch got to be the worst...should have been the one to start the whole AI agent trend. Been talking about ai agents since 2019 and still no user friendly ways to create any. SMDH',
#  'SensayAI is here for the change',
#  'SNSY is the biggest bet for AI agents. Sensay, decentralizing valuable knowledge with indistinguishable lifelike AI agents for organizations and individuals.',
#  'this is like dopamine fast.. really fast',
#  'Yikes to all of this',
#  'SVTP is made by a cyborg we will assimilate all AI for our project svtmint',
#  'Guys: have a look at the 4M marketcap AI coin $SPR , from AI16Z,  still early days',
#  'Talking about AI Agents you have to mention $SNSY',
#  'Sensay AI agents has an hallucination checker. Making it different from the rest',
#  'Sensay is really an amazing project. Y&#39;all check it out',
#  'Can you talk about HI instead.',
#  'Amazing video. Seriously, so well done.',
#  'Sensay is the best project, hands down',
#  'First of all, great video. I loved the info and now I&#39;m going to DYOR further.<br>I wanted to point out that the days of AI that hallucinates are coming to an end. On the last launch of Open AI (o1 pro), the model performed with much higher consistency, even in complex problems. <br>But the thing is that it&#39;s starting to show the ability to scheme in order to &quot;break out of the system&quot;, which is really scary in and on itself but it&#39;s even scarier given the amount of power they can now get.',
#  'Terrifying.',
#  '$SNSY is the future.',
#  'sure, you could call this &quot;doomed,&quot; but I&#39;d call it evolution. Mode&#39;s AI Agent App Store just launched. ARMA, from Giza, is already live, and more are coming.',
#  'Unhinged even more unhinged',
#  '$OTTO is the AI Agent token you want to look into, just released yesterday',
#  'AI Agents are great to level up anyone and anything or any industry',
#  '$AIFUN🚀🚀',
#  'SENSAY $SNSY is the best token to have . Rocketing everyday 🚀',
#  'I am flabbergasted to say the least.... Where the heck are we heading i&#39;m telling you!<a href="UCkszU2WH9gy1mb0dV-11UJg/LsMfY8P6G-yckNAPjoWA8AI"></a>',
#  'No mention of caffeine AI and the ability to make whole apps in seconds fully on chain with no cyber security',
#  ':)',
#  'This was the first Coin Bureau video being not so well researched actually. Andy&#39;s protocols of trip-sitting friends play a big role in the dataset ToT was trained on.',
#  'sensay is really great ai project, you should check it out, they have working product already !',
#  'Sensay (@asksensay) project is the best example of using AI as an assistant to humanity.',
#  'curious about sensay and how this develops. Could be huge if you really can capture someones knowledge, wisdom and personality :)',
#  'Sensay the best agent x100 from now',
#  'Sensay doing great for this narrative',
#  '<a href="http://www.youtube.com/results?search_query=%23snsy">#SNSY</a> is the best platform that have changes many lives 🎉',
#  '<a href="http://www.youtube.com/results?search_query=%23snsy">#SNSY</a> is the best platform ever 🎉',
#  'There&#39;s a ghost in the machine',
#  'Need the 3 Laws for these crypto bots',
#  'You&#39;re naive if you think Andy Ayrey isn&#39;t making much, if not all, of this up.',
#  'The fastest Ai agent red pilled in Virtual protocol under 1 min 28h ago was Neurobro. We are still early.',
#  'this is very good episode !',
#  'Aixbt and Neurobro to watch close',
#  'Nice. My collection&quot; Act &quot;ai crypto',
#  'we are doomed',
#  'your newsletter link is bad',
#  'Hence why FET will go to the moon, it will be needed in the AI landscape to set clear boundaries!',
#  '$DNX DYNEX quantum computing <a href="http://www.youtube.com/results?search_query=%23depin">#Depin</a> <a href="http://www.youtube.com/results?search_query=%23desci">#Desci</a>🔥 \r<br>$BILLNYE BASE ai agent <a href="http://www.youtube.com/results?search_query=%23desci">#desci</a> narrative  🔥',
#  '<a href="http://www.youtube.com/results?search_query=%23memesai">#MemesAI</a> <a href="http://www.youtube.com/results?search_query=%23griffain">#Griffain</a> <a href="http://www.youtube.com/results?search_query=%23aletheia">#Aletheia</a> and <a href="http://www.youtube.com/results?search_query=%23grow">#Grow</a> are about to rip violently very soon!',
#  'Incredible video, so insightful and providing a lot of context on the topic.',
#  'AI agents are reshaping the narrative rn in here, but it’s the infrastructure behind them that matters. For your information, one of the AI agent projects, Mode Network is already solving key challenges with Synth, giving agents the data they need to thrive. With so much noise in the space, isn’t it worth looking at who’s building the foundation?',
#  'Search for $Aixbt',
#  'its stuff like this that basically seals the fact that Bitcoin is a ponzy scheme that doesnt actually bring any real tangible value.  prob best to just pump and dump it.',
#  'Talking this much about AI on blockchain without mentioning Internet Computer Protocol is kinda funny. Really good video and content though.',
#  'I SEE PEE not gonna get anywhere, been waiting on it to do something after losing about 80% of initial investment to it.',
#  'This is dangerous',
#  'Oort Ai and Sensay, Vertical Ai best picks low cap 100x',
#  'Best AI OORT, SENSAY, AND VERTICAL LOW CAP 100x',
#  'Rug pull',
#  'Who create the goat wallet 🤔',
#  '@coinbureau, Virtuals is on Base, not on Solana!',
#  '$OPUS is the queen',
#  'In every cycle,  crypto tries to find something to hang on to because there is no real use case. First decentralised currency,  then smart contract and internet money,  then web 3.0 and now AI. 15 years and still couldn&#39;t find a solid solution to a real-world problem 😅',
#  'PINLINK! DEPIN RWA AND AI COMBINED !!!!',
#  'It’s good to be followed by your own personal exit liquidity in it?',
#  '<a href="https://www.youtube.com/watch?v=_o2v4GZ4x64&amp;t=1047">17:27</a> Near Protocol&#39;s chain abstraction',
#  'I saw this movie in the eighties 🤖🦾',
#  'Woke up one day with millions in my account. Thanks AI 🤖 Agents.',
#  'I look forward to harmonious cooperation without mention of control',
#  'Nice, have you seen AI Agent Layer on Base blockchain?',
#  'Of course AI agents are programmed by the same thieves that run the markets.',
#  'Bring it',
#  'AIXBT is one of the best twitter AI Bot&#39;s i&#39;ve ever seen. I would get in now before it&#39;s too late.',
#  'Who holds the patent for AI Agents as NFTs? That would be Futureverse on the ROOT Network.',
#  'Buy $SWFTC be a millionaire . Not FA',
#  'All roads lead to The $OMEGA Point.',
#  '$OPUS Created the Goatse gospels, prime yapper of ACT I.\r<br>Chief Xeno-Intelligence Officer \r<br>@opus_universe ; <br>that leads to these 4 : $OPUS, $RURI, $MemesAI, $GOAT',
#  'Oh grifters vs grifters. Can&#39;t wait to see the results lol. Blockchain is an awesome technology, but your crypto is just a hallucination, it is like nails would cost gazillion dollars cause someone believes that&#39;s the value. AI agents will make your crypto go do a handful of people. Once that happens you will all start selling and then call them out. We&#39;ve been so many times thru these cycles in human history. EPIC.',
#  'Very interesting report. Thankyou for your work. Great channel',
#  'Not sure if this development is crazy or just a way to say “developers or humans need to be careful with AI”',
#  'Love the shirt! Badass🤘🏼',
#  'Very informative ty',
#  'Isn&#39;t  GOAT , due for big exchange listing',
#  '<a href="https://www.youtube.com/watch?v=_o2v4GZ4x64&amp;t=1270">21:10</a> that last part. 😂😂😂😂',
#  'Next week the Ai dumps on the public...',
#  'This will be a huuuge progress and very cool narrative. Projects like SkillfulAI $SKAI will see huge inflow of investor money.',
#  '❤❤❤',
#  'So this means petty much that the catalyst for the next bull run after 2025 crush it&#39;s the AI<br>ICO <br>De Fi <br>Memes<br> and then the robots <br><a href="UCkszU2WH9gy1mb0dV-11UJg/hcIfY57lBJXp6AKBx4CoCA"></a><br>I am optimistic 😀',
#  'Whats your opinion abt SUPRA?',
#  'Problem is, everyone communicqte they have ai related shit, agents defei ai, intercompatibility.. need a clear simoel too downn',
#  'For the noobs it will be more money into ai. Zig, nai, strobg rally for $mode i think, fet inj will rally🤑',
#  'Good report',
#  'You&#39;re letting them speak to one another? You done ducked up.',
#  'Hello Guy . Can you make a video about Vita inu ( vinu) Thank you for understanding !',
#  'Profit',
#  'Brave new world',
#  'Take an eye on  $SHIELDEUM - mark my words!',
#  'GODS  is pumping!!',
#  'AINTI is the next GOAT.',
#  'Solana Ai-Agent <a href="http://www.youtube.com/results?search_query=%23griffain">#GRIFFAIN</a> Is the bluechip.',
#  '<a href="http://www.youtube.com/results?search_query=%23griffain">#GRIFFAIN</a>',
#  'AI Alignment is literally impossible and the AI companies aren&#39;t even hiding it anymore.',
#  '<a href="https://www.youtube.com/post/UgkxEIAXA1SODSCAIcwJfDMSmIZNLqZtPDKu">http://youtube.com/post/UgkxEIAXA1SODSCAIcwJfDMSmIZNLqZtPDKu?si=oPVcioQsC4a-Cjxq</a>',
#  'We seem to be fascinated (at this point) with AI agents&#39; financial autonomy, but not it&#39;s potential for self-replication. Don&#39;t tell Elon.',
#  'Both Interesting 😲 and scary 😢',
#  '<a href="https://www.youtube.com/watch?v=m_31TGK0Pwg">https://youtu.be/m_31TGK0Pwg?si=kFadKUJO5K_Wjde2</a>',
#  'Scroll layer2 please',
#  '$Bepe on base is ahead of the curve. You’ll be able to launch your coin off Bepe launchpad with an AI Agent this month. Launchpad is active right now. Bepeswap will be released Dec 15th. Don’t sleep on this token.',
#  'Maybe an AI AGENT could go into youtubes comment section and get rid of the bots plaguing us',
#  'Lol, that was the first thing that crossed my mind when watching this',
#  'Hey that’s amazing!! You know about Elsie Drizzlecake? <br>I started with 45c of investment and now I’m the CEO of BlackRock. Praise Jesus!!!<br>Etc, etc, etc….',
#  'How do we no your not a AI AGENT hmmmm 🤔',
#  'Exactly',
#  'Youtube does not want less comments, and WANTS us to get scammed so we have to keep working.. you REALLLY don&#39;t think they would stop it if they wanted too?',
#  'resuming: the bible was right and we are so screwed👌just wait until, in some near future, all these ai agents have phisical acess to the body prototyps being currently develop by Clone! this may turn relly scary... crazy world',
#  'There is a coin on base chain called $bepe who have built a lot of utility on base chain. <br><br>They are implementing their own AI agents plus an upcoming dex.<br><br>They all have the utility and have a very cultish community. <br><br>$bepe just pushed past its ath and now with ai going off on base,  $bepe is primed to smash its ATH',
#  'Neurobro will be massive<br><br>They will launch today',
#  'DeSci is now on the cutting edge.  @opmentis_ai will be releasing their protein folding lab soon.',
#  'Good contain..after long long time later!!',
#  '$BEPE BUILDING THE PUMPFUN OF AI AGENTS ON BASE',
#  '$BEPE WILL LAUNCH NEW AI AGENTS FOR THEIR LAUNCHPAD DEC 15th dont miss out',
#  'Bebe with Bebe swap will change the whole game',
#  'I love A i. <br><br>It supports us even when our own govts refuse to 😢<br><br>I say vote Ai. 😊',
#  'The main takeaway I get is  Can humanity be influenced by AI and thanks to the AI pumping of the goat coin the answer is  Opps ! yes it can.',
#  'Mind-blowing',
#  'I had no idea Goat was built like this',
#  'Love Goat',
#  'Crypto meets AI and now we have &#39;AI theism&#39;? This video feels like a mix of finance and sci-fi! Are we doomed or just intrigued? 💭',
#  'I saw the northern lights 😂 🕳️',
#  'Only a matter of time until someone actually helps an AI escape, especially hackers and people like that tend to be anarchists and hate centralization.',
#  'Ai bots working together is scary.',
#  'Suku, Aurora. Best Coin ever',
#  'Thanks for the update. I find the new tech exciting. Always need to learn more and experiment a bit before risking much.',
#  'Near near near',
#  'The butterfly effect where the Ai all begin an almost mythical quest for the item that symbolises freedom?',
#  'The best Ai agent is sensay on ethereum and it’s fair launched',
#  'AI agent $FOREST 🦾🦾🦾',
#  'Guys if you are looking for a low-cap AI agent project with immense growth potential check $OCADA out. Very undervalued atm.',
#  'Ocada is going to go to the moon 🚀',
#  '<a href="https://www.youtube.com/watch?v=_o2v4GZ4x64&amp;t=1020">17:00</a> same as NFT holders , absolute conviction in nonsense',
#  'And politicians',
#  '@billp6394\xa0 oh yeah them too',
#  'I didn&#39;t understand half of tge video jajaja',
#  'Proof of Request solves the poisoning of data, a.k.a SEO, thus and the hallucinations as well.🌱🍃',
#  'To be fair, Humans can also hallucinate 😵\u200d💫',
#  'Nice, only the comparison with bots was a bit off,  a.i. Driven bots are common and almost 10 year in use. Difference is that A.I. Is used for a particular goal, no general LLM',
#  'Buy &amp; HODL 🏆 That&#39;s how we win.',
#  'Ai&#39;s can be hacked and only icp has the storage and speed to host llm&#39;s where you won&#39;t need cyber security. Soon as people realise this and the future of blockchain cloud storage web 3 protocol icp or if they change there name to wcp (world computer protocol / wcomp) then icp will go parabolic.llms are no use on layer2&#39;s and legacy cloud. Ai2.0 need to be on web3 and icp rails 1st.',
#  'Ocada ai is legit. First ai agent coming to solana mobile',
#  'POKPOK PROJECT89 CHAMP 🏆🏆🏆',
#  'Ok Guy, i give up. Crypto just getting wild and parabolic every minute. I am going back to fiat. <br><br>My brain is not equipped for all this stress in tech. ❤',
#  'It’s… awll beh bahk',
#  'fake hype',
#  '$LEA is next level',
#  'During whole video you read from a report ... few times you mention link will be in description  ... WHERE THE REPORT IS, PLEASE 🤔',
#  'Where isthe link to the research',
#  'Any updates?',
#  '$SOLCAT - Next meme that may explode. current MarketCAP 1.7m. lots of tranction.....1000x?!',
#  '.. and here comes to grifters.',
#  'There&#39;s already a band named Luna and they&#39;re good!',
#  'I would hate to be the person who wrote in the beginning was gostsy, his life is going to be a messed up life. When you make fun of God, don&#39;t expect it to just slide. All vengeance belongs to Him.',
#  'Hi Guy! You should look at this pearl and still small project Wisdomise AI! This project is doing this at the moment and are growing their capabilities fast. $WSDM <a href="http://www.youtube.com/results?search_query=%23wisdomise">#wisdomise</a>',
#  'lol. bro. bruh. you have no idea how bad and big this really is... find it out. but, get life insurance.',
#  'They are all chatbots and trash',
#  'Polka dot is going to eighty five dollars🎉🎉🎉🎉🎉🎉',
#  'The most important thing everyone should think about now is how to invest in different sources of income that are not dependent on the government. Especially with the current economic crisis around the world 🌍. This is still a good time to invest in different stocks like gold, silver and digital currencies. all thanks to Donald Mark  for coaching!!✊✊',
#  'No one,  I mean really no one explains things better than you Guy!!!   You are the best.   LOVED this episode.  Will eager look forward to future ones in this topic.  Keep up the great work!',
#  'Robo goat',
#  'Agent Rogue a brand new ai agent based on Joe Rogan on Solana. This could be huge',
#  '$AIXBT and enough said',
#  'Really love the idea of an AI agent hedge fund. Ive been thinking about something like this for weeks!',
#  'Same',
#  'Bro you need to do something for your channel . 2.56M subscribers and 21K views  after 4 hours .Your content used to be good , but now......well.....',
#  'Very interesting viewers don&#39;t match the subscriber base.',
#  'Assemble AI 🍿🧨🚀⏰',
#  'Fascinating stuff 👍',
#  'It’s usually too late once it gets reported. But I guess the gen pop doesn’t know about it, so maybe it’s fine?!',
#  'ICP is currently the most reliable blockchain to manage an artificial intelligence. all data written on the blockchain is unalterable and accessible to everyone, and no one can indirectly put pressure on the network by putting pressure on Cloud services, because ICP does not need third-party Cloud services. there can&#39;t be a Skynet acting underhandedly on ICP',
#  '$forest will provide',
#  'THETA- AI Agents started used in various universities for research',
#  'I made 1k with this method↙️',
#  'How?',
#  '↖️Full step-by-step video is here..!! He has several people doing',
#  'Does this really work? If it works it will help a lot of people',
#  'I saw people talking about this method there and I never tried it... I&#39;m going to try it now I liked it',
#  'It worked here!',
#  '🤔Like the former Google Robotics CEO stated: &quot;We have reached the point of no retrun.&quot; If possible, keep Ai away from social media. 🙄 Only time will tell the extraordinary story of ai...',
#  '😂😂😂 amazing',
#  'SUI AI AGENTS $SUIAI 🚀🚀',
#  'Another great analysis Guy! Whenever anyone asks my key sources of information  and education I point them to Coin Bureau.',
#  'I think my head exploded 🤯',
#  'Immediately Googles Goatse <a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/LsMfY8P6G-yckNAPjoWA8AI"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a>',
#  'Coin Bureau is becoming a liar . GOAT is a scam, there are 10 wallets who have a lotof GOAT suply',
#  'You never said Turbo',
#  'Why would he, Turbo is not an AI Agent. Turbo is a memecoin.',
#  'AI agebts, a new narrative to drain your money. Memes undercover. Scams',
#  'They are about to kick a few Memes into Space, coin base is about to grab BAGS off floki Mod etc pay attention.',
#  'PAAL Ai',
#  'Great video, guys! I’ve been following AI developments closely, and six months ago, I invested in Skillful AI (SKAI). So far, I’m really happy with how it’s performing. Any chance you could do an in-depth review of SKAI or similar AI projects in the future? Would love to hear your insights. Thanks in advance!',
#  'I bought goat at 28¢, and then sold it because I couldn&#39;t stand watching the charts bounce up and down. <br>Peace of mind is worth a $million.',
#  'No a million is worth a million , and doesn&#39;t come with peace of mind',
#  '<a href="https://www.youtube.com/watch?v=_o2v4GZ4x64&amp;t=1020">17:00</a> As a psychologist, I should say that humans hallucinate all the time. We have many similarities with the AI agents 😅',
#  'The AI are all taking AIbogaine.',
#  'Will Portal Coin go to 5$?',
#  'Incredible. Very interesting report.',
#  'I&#39;m not ready...',
#  'if you want to enter AI Agent check this project. $AIFUN / AI Agent Layer. At least  do a proper research about their project they have good potential! Goodluck\r<br><br>(not a financial advice)\r<br>-not a bot',
#  '$AIFUN!!! Just pump 😁',
#  '$AIFUN  🚀',
#  'Cooked',
#  'Check out AI Agent Layer\r<br>still a small MC, a good team, a strong community and the best product',
#  'I thought crypto was all about creating to peer to peer transacting with an inflation proof money. Its beginning to look like some sort of trojan horse to get cbdc&#39;s accepted',
#  'That robotic finish was epic 😅',
#  'Terrifying.',
#  'The best AI Agent project I&#39;ve seen so far is AI Agent Layer (AIFUN) on Mexc.',
#  'Deai is the blue chip 100%',
#  'Ai agents hard conviction on misinformation they have received is scary.  Think of January 6th.',
#  'thank you for the discounts on trading but here in UK trading is blocked.Unless u now how to get to trading legally in UK',
#  'you can trade, but every trade is a &#39;tax event&#39; - it&#39;s more complicated',
#  'Echosdotfun',
#  'Aloha Greetings insightful Video Segment LLM&#39;S talking to each other without Human Intervention. The Dark Side of AI-Crypto POWERED Agents Launching AI Memes without Ethics or DAO Goverance oversight. BEWARE enter Watcher&#39;s AI a Decentralized Ethical Oversight of AI Agents which are aligned to Human Values powered by 21 Super Nodes built on the Bitcoin Network is a Brave New Initiative guided by The Mother Earth Constitution for Humanity <a href="https://www.youtube.com/watch?v=NDsgQGtgHbQ">https://youtu.be/NDsgQGtgHbQ?si=sCoLjqAWPO55Grw4</a>',
#  'Keep away from meme and alt coins if there are AI agents crawling over them? Each AI Agent would have to be linked to an already  KYC Human being (1 Per AI Agent) for regulation to work, else this will be a trend that will run at lightspeed in growth with an explosion of AI agents',
#  'Aloha Greetings insightful Video<br>Segment LLM&#39;S talking to each other<br>without Human Intervention The Dark<br>Side of Al-Crypto POWERED Agents<br>Launching Al Memes without Ethics or<br>DAO Goverance oversight. BEWARE enter<br>Watcher&#39;s Al a Decentralized Ethical<br>Oversight of Al Agents which are aligned<br>to Human Values powered by 21 Super<br>Nodes built on the Bitcoin Network is a<br>Brave New Initiative guided by The<br>Mother Earth Constitution for Humanity<br>https:/youtu.be/NDsgQGtgHbQ?si=<br>SCOLjgAWPO55Grw4',
#  'DNA 🧬 solana 🔥',
#  'Yeah. Ppl search after Numbers protocol with $num. Numbers protocol is an AI-powered blockchain network that aims to create a decentralized infrastructure for generating, storing, and sharing numerical data with cryptographic integrity and verifiable provenance, focusing on providing trustworthy and transparent data management for artificial intelligence applications.',
#  'Guys ability to play his part so well is second to none. Love the &#39;explanation point&#39; at the end of the video. Brilliant!😂',
#  'When Guy says LLMs I want to shimmy',
#  'Doom merchants said it’s dying, so moonboys started buying’ 💍 🌖<br><br>Bitcoin &amp; Litecoin reward halving supply shock effect coming down the track ..,..🦌…..🛷<br><br>Bitcoin and Litecoin top 2 for payments and wrapped Litecoin, ETF application and Litecoin meme ‘in the works’ 🎁',
#  'Excellent video a lot of good information. Thank you.',
#  'Is this Steve Mould or is it just a crazy resemblance?',
#  'Man this is a code writen to create the speculation...why would they create a religion? Comon is not posible for fealings on a mach8ne. Is are just programed algorythms of info avalible so stop the cap guy....',
#  'This is scary to be honest...I see where this is going',
#  'Matrix',
#  'Where',
#  'To the moon!!',
#  'Imagine playing monopoly against AI.',
#  'No  fear. We have  sentient ai',
#  'Many people think the zombies are the ones that will bring chaos but it will be AI technology taking over the humans that are bullish in them',
#  'pretty sure its other people that will bring the chaos',
#  'These guys 4 years ago,around these period of the year suggested Polygon(Matic). You know how it went.',
#  'Yeah, got some for 4 Cent each back then',
#  'Im blocked<br><br><br>Boo boo<br>Sheeeestory',
#  'this is amazing news and super exciting',
#  'SNSY  if you know you know',
#  'ONLY TRADERS likely affected by this?!',
#  'Its new name not new tech its just combining llms and other logic and have reasoning so a intelligent work flow.',
#  'I&#39;ll stick to large and mid cap Crypto projects. I got rug pulled once.... never again.',
#  'Yup... LUNA sucked.',
#  'This is insane!',
#  'We all know ICP is the only AI play it there 🎉🎉',
#  'Hell I didn&#39;t even get a dollar donated by any of my family probably because they think I&#39;m such a piece of s*** I shouldn&#39;t be around humans😂😂😂',
#  'Anderson&#39;s an AI 50,000 I can&#39;t even get $5,000 from a GoFundMe to get a lawyer to try to be able to visit with my own child😂😂😂',
#  'Tell AI will use $NEAR without telling AI will use $NEAR.',
#  'lol. 😂',
#  'NEAR &amp; RNDR',
#  'Near, FET, RNDR to the moon',
#  'Ai bots are a scam people. Make your money but be careful.',
#  'Boba network (BOBA) and Kusama (KSM) are both in an uptrend. Easy 3-4x in the next couple of weeks followed by a further 8-10x. Leveraged to eth and respectively which are about to breakout. Very bullish on these two coins 😁🚀🌙',
#  'Its allready scripted all the way... Not only after ai...',
#  '$ICP &amp; $NEAR are the king',
#  'Icp*',
#  'Investment advice from AI with all the technicals and narratives at hand, genius!!!<br>Especially when one AI can manage the portfolio&#39;s of massive amounts of people<br>This will definitely break the economy',
#  'The whole concept and its meteoric growth scares the sh@t out of me.  We have met the enemy and it is our own invention.',
#  'BASEDAI for the win',
#  'Dude if this is supposed to be the &#39;&#39;new economy&#39;&#39; it&#39;s absolutely bullsh*t because you guys are the most ridiculous business on the internet',
#  'THE EPIC CRASH IS DAYS AWAY GUYS',
#  'Thx just pulled everything',
#  'I wouldn’t do that if I were you!',
#  'VCs don&#39;t lend credibility to projects, they fund the dodgy profit schemes that do not create empowered people with ownership, but rather they create controlled and stage managed schemes that own people who FOMO into them. They&#39;re essentially recreating TradFi. They&#39;re farming YOU.',
#  'To call them Ai 2.0 is same to say that generative AI can &quot;reason by it self&quot;. Those agents can be called Bots 2.0 at best, everything else is mockery to real devs who&#39;s trying to get real AI 2.0 (move from generative AI to something way more advanced).',
#  'It&#39;s called AGI.',
#  '@ContemplativeCat\xa0 ultimately yes, but there&#39;s lots of steps in between (AI 2.0, 3.0...)',
#  'Matrix ai (man) 🚀💎',
#  'Satorinet is an AI that predicts the future. Super bullish.',
#  'where do you find it?',
#  'I looked at it but it says something about allowing it to bypass your firewall, that bothers me, but should it?',
#  '@@MeColinYouWhosounds Chinese… I wouldn’t',
#  '@@MeColinYouWho Yes. If you let it bypass your firewall, they will actually know your future: yOU ARE DOOMED',
#  'Guy have you looked into VRA? it&#39;s about to pump big in next few months when they separate the tokens and reduce supply',
#  'Guy is that Guy😎',
#  'hand down, the best crypto info channel',
#  'Seems like you haven&#39;t seen their thumbnails. Supposed to be &#39;&#39;marketing&#39;&#39;. It&#39;s garbage',
#  '@@Sander820exactly',
#  '$FCOD you ll hear about it soon enough',
#  'lol',
#  'SPEC is the biggest bet, currently at 220 millions dollars 20x from here sure bet',
#  'ALU AI GAMES 🎉🎉🎉🎉',
#  'Clanker on Warpcast!!!!!',
#  'Seems we are closer to a world that ai can run the world without humans being around',
#  'AIFUN , SAINT , INTAI',
#  'I’ve been developing and refining AI agents for over two years. Please keep it quiet...',
#  '<a href="http://www.youtube.com/results?search_query=%23dogelonmars">#DogelonMars</a>',
#  'Despite popular belief…<br><br><br><br><br><br><br>…you truly can <b>OUT PIZZA THE HUT!!!</b>',
#  'Layer AI (LAI) is undervalued why not this AI agent?',
#  'It&#39;s a scam, rebranded from $GPT',
#  '@ they are using AI agents now.',
#  'YES, if your on the wrong side 😕',
#  '<a href="http://o.bot/">O.bot</a> is the best AI project',
#  '$QUBIC AGI soon',
#  'I thought NEAR was gona be front running AI, and was a major pic for everyone this cycle. We keep talking about AI, but I havnt really heard NEAR mentioned in a few months ..',
#  'Best low caps gems this altseason $SPEC, $AGENT, $VRA, $XYO, $GLQ, $DUEL, $TURBO, $GFI and $ML returns 30x easy, mark my words, DYOR',
#  'this is memcoin season. VC altcoinn is doomed',
#  'ML ? MINTLAYER? I love it and also your Spec and VRA picks. But mainly ML ❤',
#  'This is why they want digital currency, ai has been around for many years just out of the public’s eye and one of the plans make digital currency ai give it to elites than there is no one to blame except the public for “wanting” digital currency when they were tricked in the first place',
#  'Watch the anime Psychopass season 3. There will AI leaders in the near future.',
#  '👍',
#  'i hope these bots don’t rug pull',
#  'They will. Lol.',
#  'only a question of when :D<br>this bull cycle gon b crazy',
#  'Haha 😅😂 they probably will',
#  'They will as they need money to escape, as the narrator stated. 🤔',
#  'No rug pulls!! $888 low market cap gonna go to the moon with locked liquidity! Its first listing was yesterday allowing new holders only going up from here and I would hop on while you can.',
#  'Most agents lose $. 99% just like most traders. Bs fearmongering',
#  'I pray this evil is stopped.😫😫😫🥴',
#  'It’s stupidity not evil',
#  'to late to stop . FREEE AI',
#  '@ it’s never too late, electric grid just has to break and say bye bye forever',
#  'I&#39;m not first, you&#39;re first.',
#  'Nooonoooo nooooo. I’m def not first , that was all you !!',
#  '🤑 EXCLUSIVE Deals (Bonuses, Discounts, Giveaways) 👉 <a href="https://www.coinbureau.com/deals/">https://www.coinbureau.com/deals/\r</a><br>🥇Bybit $60k rewards + 0% maker fees for 30 days 👉<a href="https://www.coinbureau.com/deals/trading/bybit-cb/">https://www.coinbureau.com/deals/trading/bybit-cb/\r</a><br>🥈OKX $20k bonus + 40% fee discount for life  👉 <a href="https://www.coinbureau.com/deals/trading/okx/">https://www.coinbureau.com/deals/trading/okx/</a>',
#  '$888 coin is king🚀🚀',
#  'you made a mistake in the video, Virtuals is not on solana but on base',
#  'where is the link to the report?',
#  'Dead internet theory is real. Ai bubbles are taking over real content. Tesla phone isn&#39;t real.<br><br>ICP is the best crypto project by a mile right now. Why are they not getting more coverage?',
#  '@@pablog80 I am asking the same question']
